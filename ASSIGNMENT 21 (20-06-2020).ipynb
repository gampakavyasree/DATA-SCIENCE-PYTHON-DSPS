# %% [markdown]
# #CSE-221710306018-KAVYASREEGAMPA

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv")

# %%
data
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
#1.Check the data types and summary statistics of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
# name_of_city                      493 non-null object
# state_code                        493 non-null int64
# state_name                        493 non-null object
# dist_code                         493 non-null int64
# population_total                  493 non-null int64
# population_male                   493 non-null int64
# population_female                 493 non-null int64
# 0-6_population_total              493 non-null int64
# 0-6_population_male               493 non-null int64
# 0-6_population_female             493 non-null int64
# literates_total                   493 non-null int64
# literates_male                    493 non-null int64
# literates_female                  493 non-null int64
# sex_ratio                         493 non-null int64
# child_sex_ratio                   493 non-null int64
# effective_literacy_rate_total     493 non-null float64
# ...

# %%
data.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# ...

# %%
#2.Select random columns as Series and random columns as dataframe
df = data.sample(axis=1,n=3)
df
# Out:
#      dist_code  0-6_population_male               location
# 0            9                 8587  30.1452928,74.1993043
# 1            7                 6186   21.257584,77.5086754
# 2            1                 6731   19.0809075,79.560344
# 3           24                12063  22.7834741,86.1576889
# 4           21                 9355  15.6322227,77.2728368
# ..         ...                  ...                    ...
# 488         12                10495  18.1066576,83.3955506
# 489          9                28434  17.9689008,79.5940544
# 490          8                 5139   20.745319,78.6021946
# 491          3                12556  30.1290485,77.2673901
# 492         14                 5894  20.3887937,78.1204073
#
# [493 rows x 3 columns]

# %%
#3. Convert the data type of integer cols to float
dfint = data.select_dtypes(include='int64')
dfint=dfint.astype(float)
dfint
# Out:
#      state_code  dist_code  population_total  population_male  \
# 0           3.0        9.0          145238.0          76840.0
# 1          27.0        7.0          112293.0          58256.0
# 2          28.0        1.0          117388.0          59232.0
# 3          20.0       24.0          173988.0          91495.0
# 4          28.0       21.0          166537.0          82743.0
# ..          ...        ...               ...              ...
# 488        28.0       12.0          227533.0         111596.0
# 489        28.0        9.0          620116.0         310400.0
# 490        27.0        8.0          105543.0          53241.0
# 491         6.0        3.0          216628.0         115404.0
# 492        27.0       14.0          116714.0          58717.0
#
#      population_female  0-6_population_total  0-6_population_male  \
# 0              68398.0               15870.0               8587.0
# 1              54037.0               11810.0               6186.0
# ...

# %%
#3. Convert the data type of float cols to integer
dffloat=data.select_dtypes(include='float64')
dffloat=dffloat.astype(int)
dffloat
# Out:
#      effective_literacy_rate_total  effective_literacy_rate_male  \
# 0                               79                            85
# 1                               91                            94
# 2                               80                            88
# 3                               83                            89
# 4                               68                            76
# ..                             ...                           ...
# 488                             81                            88
# 489                             84                            91
# 490                             94                            97
# 491                             85                            89
# 492                             91                            95
#
#      effective_literacy_rate_female
# 0                                73
# 1                                89
# 2                                72
# 3                                76
# ...

# %%
#4.Visualize the missing values through heatmap
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data.isnull())

# %%
#5.Dropt the duplicate values if found any
data.duplicated()  ## no duplicates found
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 488    False
# 489    False
# 490    False
# 491    False
# 492    False
# Length: 493, dtype: bool

# %%
#6.Get the row which has highest population
data[data.population_total == data.population_total.max()]
# Out:
#         name_of_city  state_code   state_name  dist_code  population_total  \
# 185  Greater Mumbai           27  MAHARASHTRA         99          12478447
#
#      population_male  population_female  0-6_population_total  \
# 185          6736815            5741632               1139146
#
#      0-6_population_male  0-6_population_female  ...  literates_female  \
# 185               599007                 540139  ...           4509812
#
#      sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 185        852              902                          90.28
#
#      effective_literacy_rate_male  effective_literacy_rate_female  \
# 185                         93.32                            86.7
#
#             location  total_graduates male_graduates  female_graduates
# 185  19.0760,72.8777          1802371         964964            837407
#
# [1 rows x 22 columns]

# %%
#7. Calculate the mean of the population total grouped by States and sort the population total in ascending order
df1=data.groupby('state_name')['population_total'].mean()
df1.sort_values()
# Out:
# state_name
# ANDAMAN & NICOBAR ISLANDS    100608.000000
# NAGALAND                     123777.000000
# MEGHALAYA                    143007.000000
# HIMACHAL PRADESH             169758.000000
# UTTARAKHAND                  223399.500000
# BIHAR                        258250.615385
# MANIPUR                      264986.000000
# PUDUCHERRY                   270900.500000
# MIZORAM                      291822.000000
# WEST BENGAL                  296123.098361
# HARYANA                      297611.150000
# ORISSA                       300323.400000
# MADHYA PRADESH               344471.593750
# ASSAM                        347788.500000
# CHHATTISGARH                 348657.555556
# RAJASTHAN                    360104.000000
# PUNJAB                       363867.250000
# KERALA                       393710.428571
# TRIPURA                      399688.000000
# UTTAR PRADESH                401633.730159
# JHARKHAND                    427825.900000
# ...

# %%
#7. plot a horizontal bar chart for the mean of the population total grouped by States in ascending order
df1.plot.barh(figsize=(5,5))

# %%
#9.Create a dataframe of five cities which have hoghest population
data1=data.sort_values(by='population_total',ascending=False).head(5)
data1
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 141              Delhi            7    NCT OF DELHI         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 7            Ahmadabad           24         GUJARAT          7
#
#      population_total  population_male  population_female  \
# 185          12478447          6736815            5741632
# 141          11007835          5871362            5136473
# 72            8425970          4401299            4024671
# 184           6809970          3500802            3309168
# 7             5570585          2935869            2634716
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 185               1139146               599007                 540139  ...
# 141               1209275               647938                 561337  ...
# ...

# %%
#8.Create a dataframe of five cities which have lowest population
data2=data.sort_values(by='population_total',ascending=True).head(5)
data2
# Out:
#     name_of_city  state_code                 state_name  dist_code  \
# 332       Nagda           23             MADHYA PRADESH         18
# 53     Banswara            8                  RAJASTHAN         27
# 211  Hinganghat           27                MAHARASHTRA          8
# 136       Datia           23             MADHYA PRADESH          5
# 376  Port Blair           35  ANDAMAN & NICOBAR ISLANDS          3
#
#      population_total  population_male  population_female  \
# 332            100036            51410              48626
# 53             100128            51240              48888
# 211            100416            51881              48535
# 136            100466            52931              47535
# 376            100608            53247              47361
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 332                 11053                 5840                   5213  ...
# ...

# %%
frames=[data1,data2]
pd.concat(frames)
# Out:
#            name_of_city  state_code                 state_name  dist_code  \
# 185     Greater Mumbai           27                MAHARASHTRA         99
# 141              Delhi            7               NCT OF DELHI         99
# 72            Bengaluru          29                  KARNATAKA         18
# 184  Greater Hyderabad           28             ANDHRA PRADESH         99
# 7            Ahmadabad           24                    GUJARAT          7
# 332              Nagda           23             MADHYA PRADESH         18
# 53            Banswara            8                  RAJASTHAN         27
# 211         Hinganghat           27                MAHARASHTRA          8
# 136              Datia           23             MADHYA PRADESH          5
# 376         Port Blair           35  ANDAMAN & NICOBAR ISLANDS          3
#
#      population_total  population_male  population_female  \
# 185          12478447          6736815            5741632
# ...
