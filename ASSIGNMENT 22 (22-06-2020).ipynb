# %% [markdown]
# #CSE-221710306018-KAVYASREEGAMPA

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #1.Read the dataset from the below path:
# https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv¶

# %%
data=pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv")

# %%
data
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
#a.Analyze the  top 5 cities with highest number of female graduates
df1=data.sort_values(by='female_graduates',ascending=False).head(5)
df1['name_of_city']
# Out:
# 141                Delhi
# 185       Greater Mumbai
# 72              Bengaluru
# 184    Greater Hyderabad
# 119              Chennai
# Name: name_of_city, dtype: object

# %%
#b.Find the 5 cities with lowest number of female graduates
#and concatenate the two dataframes of top 5 cities with  bottom 5 cities
df2=data.sort_values(by='female_graduates',ascending=True).head(5)
df2['name_of_city']
# Out:
# 131       Dabgram
# 39         Bagaha
# 234       Jamuria
# 374     Pithampur
# 323    Mustafabad
# Name: name_of_city, dtype: object

# %%
frames=[df1,df2]
pd.concat(frames)
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 141              Delhi            7    NCT OF DELHI         99
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 119            Chennai           33      TAMIL NADU          2
# 131            Dabgram           19     WEST BENGAL          2
# 39              Bagaha           10           BIHAR          1
# 234            Jamuria           19     WEST BENGAL          9
# 374          Pithampur           23  MADHYA PRADESH         21
# 323         Mustafabad            7    NCT OF DELHI          3
#
#      population_total  population_male  population_female  \
# 141          11007835          5871362            5136473
# 185          12478447          6736815            5741632
# 72            8425970          4401299            4024671
# ...

# %%
#c.Display only the rows which belong to Kerala, Bihar and Maharashtra.
data1=data.loc[(data['state_name']=='KERALA') | (data['state_name']=='BIHAR') | (data['state_name']=='MAHARASHTRA')]

# %%
data1
# Out:
#           name_of_city  state_code   state_name  dist_code  population_total  \
# 1            Achalpur           27  MAHARASHTRA          7            112293
# 8          Ahmadnagar           27  MAHARASHTRA         26            350905
# 12              Akola           27  MAHARASHTRA          5            427146
# 14          Alappuzha           32       KERALA         11            174164
# 20          Ambarnath           27  MAHARASHTRA         21            254003
# ..                 ...         ...          ...        ...               ...
# 472             Udgir           27  MAHARASHTRA         28            104063
# 475        Ulhasnagar           27  MAHARASHTRA         21            506937
# 482  Vasai Virar City           27  MAHARASHTRA         21           1221233
# 490            Wardha           27  MAHARASHTRA          8            105543
# 492          Yavatmal           27  MAHARASHTRA         14            116714
#
# ...

# %%
#d.Find the  top 10 cities with highest total graduation rate
df3=data.sort_values(by='total_graduates',ascending=False).head(10)
df3['name_of_city']
# Out:
# 141                Delhi
# 185       Greater Mumbai
# 72              Bengaluru
# 184    Greater Hyderabad
# 119              Chennai
# 274              Kolkata
# 7              Ahmadabad
# 380                 Pune
# 288              Lucknow
# 225               Jaipur
# Name: name_of_city, dtype: object

# %%
#e.Calculate the average child sex ratio of the Kerala State.
df4=data.groupby('state_name')['sex_ratio'].mean()
df4['KERALA']
# Out:
# 1066.7142857142858

# %%
#2.Q.Mean = 70 and Standard Deviation = 10. Identify how much area can be found between 70 and 90 with help of Empirical Rule.
#sol: 60-80 covers 68% of the data
50-90 covers 95% of the data, since a normal distribution curve is symmetric 70-90 contains half of 50-90¶
therefore, 70-90 covers 47.5% data
